# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Josh

# %% [markdown]
# #### _This notebook shall distil the Data Science Ecosystem._

# %% [markdown]
# __Objectives:__
# * list languages used in Data Science
# * list some related libraries
# * table of Data Science Tools
# * Some example code

# %% [markdown]
# Commonly used languages for Data Science:
# - R
# - Python
# - SQL

# %% [markdown]
# Commonly used libraries by Data Scientists include:
#
# - ggplot2(R)
# - dplyr(R)
# - carat(R)
# - matplotlib(Python)
# - pandas(Python)
# - scikitlearn(Python)

# %% [markdown]
# |Data Science Tools    |
# |-------------------   |
# |RStudio.              |
# |Jupyter Notebooks     |
# |VS code.              |

# %% [markdown]
# ### Some examples of evaluating arithmetic expressions in Python

# %%
# Simple arithmetic expression to multiply then add ints.
(3*4)+5
# Out:
# 17

# %%
# convert minutes to hours by dividing by 60
total_minutes = 200
h = total_minutes / 60
print(f"{h:.2f} hours")
# Out:
# 3.33 hours
